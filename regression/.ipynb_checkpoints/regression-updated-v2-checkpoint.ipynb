# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sal = pd.read_csv('merged_cbsa_salary.csv')

# %%
sal.head(5)
# Out:
#    Unnamed: 0   zip   function.  sup1  sup2  sup3  sup4  sup5  salary gender  \
# 0           1  1003   position1     4     4     0     0     0   77308      M
# 1           2  1003  position15     0     2     0    60     0   38120      M
# 2           3  1003  position15     1     0     0    60     2   55335      W
# 3           4  1003   position4     1     0     0    35     1   70863      W
# 4           5  1003   position9     1     0     0   100     0   56557      M
#
#   disabled       race  yearsinposition  yearsinprofession  age  cred1  cred2  \
# 0    False  Caucasian                3                 23   58   True  False
# 1    False  Caucasian                2                  2   26  False  False
# 2    False  Caucasian                5                 18   45  False  False
# 3    False  Caucasian                5                 20   55  False  False
# 4    False  Caucasian                5                  9   35  False  False
#
#      highestdegree  inst1  inst2  inst3  inst4  inst5  instbudget     city  \
# 0  Master's Degree      8      4      0    300      2      700000  Amherst
# 1  Master's Degree      8      4      0    300      2      700000  Amherst
# 2  Master's Degree      8      4      0    300      2      700000  Amherst
# 3  Master's Degree      8      4      0    300      2      700000  Amherst
# 4  Master's Degree      8      4      0    300      2      700000  Amherst
#
#   state        country category  instsize            insttype  ZCTA5   cbsa  \
# 0    MA  United States      one     28236  Public Institution   1003  44140
# 1    MA  United States      one     28236  Public Institution   1003  44140
# 2    MA  United States      one     28236  Public Institution   1003  44140
# 3    MA  United States      one     28236  Public Institution   1003  44140
# 4    MA  United States      one     28236  Public Institution   1003  44140
#
#    total_population  Median_Household_Income  no_male_hs  no_female_hs  \
# 0            626775                    52546   14.362949     12.932987
# 1            626775                    52546   14.362949     12.932987
# 2            626775                    52546   14.362949     12.932987
# 3            626775                    52546   14.362949     12.932987
# 4            626775                    52546   14.362949     12.932987
#
#        no_hs  at_least_hs_male  at_least_hs_female  at_least_hs  \
# 0  13.601186         85.637051           87.067013    86.398814
# 1  13.601186         85.637051           87.067013    86.398814
# 2  13.601186         85.637051           87.067013    86.398814
# 3  13.601186         85.637051           87.067013    86.398814
# 4  13.601186         85.637051           87.067013    86.398814
#
#    hs_some_college_male  hs_some_college_female  hs_some_college  \
# 0             49.334205               45.775748        47.438559
# 1             49.334205               45.775748        47.438559
# 2             49.334205               45.775748        47.438559
# 3             49.334205               45.775748        47.438559
# 4             49.334205               45.775748        47.438559
#
#    bachelors_male  bachelors_female  bachelors  at_least_bach_male  \
# 0       16.238875         17.224723  16.764052           28.415528
# 1       16.238875         17.224723  16.764052           28.415528
# 2       16.238875         17.224723  16.764052           28.415528
# 3       16.238875         17.224723  16.764052           28.415528
# 4       16.238875         17.224723  16.764052           28.415528
#
#    at_least_bach_female  at_least_bach  graduate_male  graduate_female  \
# 0             30.865373      29.720599      12.176653         13.64065
# 1             30.865373      29.720599      12.176653         13.64065
# 2             30.865373      29.720599      12.176653         13.64065
# 3             30.865373      29.720599      12.176653         13.64065
# 4             30.865373      29.720599      12.176653         13.64065
#
#     graduate   hispanic      white     black  native_american  asian_api  \
# 0  12.956547  17.744805  70.992781  6.424794         0.123808   2.877428
# 1  12.956547  17.744805  70.992781  6.424794         0.123808   2.877428
# 2  12.956547  17.744805  70.992781  6.424794         0.123808   2.877428
# 3  12.956547  17.744805  70.992781  6.424794         0.123808   2.877428
# 4  12.956547  17.744805  70.992781  6.424794         0.123808   2.877428
#
#    two_race_or_more  asian_api_total  latino_total  white_total  \
# 0          2.265087            18035        111220       444965
# 1          2.265087            18035        111220       444965
# 2          2.265087            18035        111220       444965
# 3          2.265087            18035        111220       444965
# 4          2.265087            18035        111220       444965
#
#    native_american_total  two_race_or_more_total  male_unemployment  \
# 0                    776                   14197           7.401061
# 1                    776                   14197           7.401061
# 2                    776                   14197           7.401061
# 3                    776                   14197           7.401061
# 4                    776                   14197           7.401061
#
#    female_unemployment       snap     renter      owner  median_rent  \
# 0             5.324355  20.137245  37.450531  62.549469          839
# 1             5.324355  20.137245  37.450531  62.549469          839
# 2             5.324355  20.137245  37.450531  62.549469          839
# 3             5.324355  20.137245  37.450531  62.549469          839
# 4             5.324355  20.137245  37.450531  62.549469          839
#
#    Sex.by.Age..Male.  Sex.by.Age..Male..Under.5.years  \
# 0             299661                            17142
# 1             299661                            17142
# 2             299661                            17142
# 3             299661                            17142
# 4             299661                            17142
#
#    Sex.by.Age..Male..5.to.9.years  Sex.by.Age..Male..10.to.14.years  \
# 0                           17784                             20137
# 1                           17784                             20137
# 2                           17784                             20137
# 3                           17784                             20137
# 4                           17784                             20137
#
#    Sex.by.Age..Male..15.to.17.years  Sex.by.Age..Male..18.and.19.years  \
# 0                             12925                              13282
# 1                             12925                              13282
# 2                             12925                              13282
# 3                             12925                              13282
# 4                             12925                              13282
#
#    Sex.by.Age..Male..20.years  Sex.by.Age..Male..21.years  \
# 0                        6855                        7193
# 1                        6855                        7193
# 2                        6855                        7193
# 3                        6855                        7193
# 4                        6855                        7193
#
#    Sex.by.Age..Male..22.to.24.years  Sex.by.Age..Male..25.to.29.years  \
# 0                             14570                             18675
# 1                             14570                             18675
# 2                             14570                             18675
# 3                             14570                             18675
# 4                             14570                             18675
#
#    Sex.by.Age..Male..30.to.34.years  Sex.by.Age..Male..35.to.39.years  \
# 0                             16889                             16331
# 1                             16889                             16331
# 2                             16889                             16331
# 3                             16889                             16331
# 4                             16889                             16331
#
#    Sex.by.Age..Male..40.to.44.years  Sex.by.Age..Male..45.to.49.years  \
# 0                             18288                             20635
# 1                             18288                             20635
# 2                             18288                             20635
# 3                             18288                             20635
# 4                             18288                             20635
#
#    Sex.by.Age..Male..50.to.54.years  Sex.by.Age..Male..55.to.59.years  \
# 0                             22168                             20978
# 1                             22168                             20978
# 2                             22168                             20978
# 3                             22168                             20978
# 4                             22168                             20978
#
#    Sex.by.Age..Male..60.and.61.years  Sex.by.Age..Male..62.to.64.years  \
# 0                               7364                             10419
# 1                               7364                             10419
# 2                               7364                             10419
# 3                               7364                             10419
# 4                               7364                             10419
#
#    Sex.by.Age..Male..65.and.66.years  Sex.by.Age..Male..67.to.69.years  \
# 0                               5654                              7326
# 1                               5654                              7326
# 2                               5654                              7326
# 3                               5654                              7326
# 4                               5654                              7326
#
#    Sex.by.Age..Male..70.to.74.years  Sex.by.Age..Male..75.to.79.years  \
# 0                              9056                              6523
# 1                              9056                              6523
# 2                              9056                              6523
# 3                              9056                              6523
# 4                              9056                              6523
#
#    Sex.by.Age..Male..80.to.84.years  Sex.by.Age..Male..85.years.and.over  \
# 0                              4904                                 4563
# 1                              4904                                 4563
# 2                              4904                                 4563
# 3                              4904                                 4563
# 4                              4904                                 4563
#
#    Sex.by.Age..Female.  Sex.by.Age..Female..Under.5.years  \
# 0               327114                              16361
# 1               327114                              16361
# 2               327114                              16361
# 3               327114                              16361
# 4               327114                              16361
#
#    Sex.by.Age..Female..5.to.9.years  Sex.by.Age..Female..10.to.14.years  \
# 0                             16896                               19646
# 1                             16896                               19646
# 2                             16896                               19646
# 3                             16896                               19646
# 4                             16896                               19646
#
#    Sex.by.Age..Female..15.to.17.years  Sex.by.Age..Female..18.and.19.years  \
# 0                               12332                                15325
# 1                               12332                                15325
# 2                               12332                                15325
# 3                               12332                                15325
# 4                               12332                                15325
#
#    Sex.by.Age..Female..20.years  Sex.by.Age..Female..21.years  \
# 0                          7781                          8217
# 1                          7781                          8217
# 2                          7781                          8217
# 3                          7781                          8217
# 4                          7781                          8217
#
#    Sex.by.Age..Female..22.to.24.years  Sex.by.Age..Female..25.to.29.years  \
# 0                               14210                               19094
# 1                               14210                               19094
# 2                               14210                               19094
# 3                               14210                               19094
# 4                               14210                               19094
#
#    Sex.by.Age..Female..30.to.34.years  Sex.by.Age..Female..35.to.39.years  \
# 0                               18307                               16918
# 1                               18307                               16918
# 2                               18307                               16918
# 3                               18307                               16918
# 4                               18307                               16918
#
#    Sex.by.Age..Female..40.to.44.years  Sex.by.Age..Female..45.to.49.years  \
# 0                               20805                               22550
# 1                               20805                               22550
# 2                               20805                               22550
# 3                               20805                               22550
# 4                               20805                               22550
#
#    Sex.by.Age..Female..50.to.54.years  Sex.by.Age..Female..55.to.59.years  \
# 0                               23987                               22144
# 1                               23987                               22144
# 2                               23987                               22144
# 3                               23987                               22144
# 4                               23987                               22144
#
#    Sex.by.Age..Female..60.and.61.years  Sex.by.Age..Female..62.to.64.years  \
# 0                                 8507                               11664
# 1                                 8507                               11664
# 2                                 8507                               11664
# 3                                 8507                               11664
# 4                                 8507                               11664
#
#    Sex.by.Age..Female..65.and.66.years  Sex.by.Age..Female..67.to.69.years  \
# 0                                 6176                                8145
# 1                                 6176                                8145
# 2                                 6176                                8145
# 3                                 6176                                8145
# 4                                 6176                                8145
#
#    Sex.by.Age..Female..70.to.74.years  Sex.by.Age..Female..75.to.79.years  \
# 0                               11045                                9123
# 1                               11045                                9123
# 2                               11045                                9123
# 3                               11045                                9123
# 4                               11045                                9123
#
#    Sex.by.Age..Female..80.to.84.years  Sex.by.Age..Female..85.years.and.over  \
# 0                                7634                                  10247
# 1                                7634                                  10247
# 2                                7634                                  10247
# 3                                7634                                  10247
# 4                                7634                                  10247
#
#     under_18  over_65  commute_over_60  full_time  part_time  \
# 0  21.255315  14.4224         5.349726    68.4447    31.5553
# 1  21.255315  14.4224         5.349726    68.4447    31.5553
# 2  21.255315  14.4224         5.349726    68.4447    31.5553
# 3  21.255315  14.4224         5.349726    68.4447    31.5553
# 4  21.255315  14.4224         5.349726    68.4447    31.5553
#
#    high_rent_burden  extreme_rent_burden  foreign_born   US_born  \
# 0         51.773074            28.127576       8.83443  91.16557
# 1         51.773074            28.127576       8.83443  91.16557
# 2         51.773074            28.127576       8.83443  91.16557
# 3         51.773074            28.127576       8.83443  91.16557
# 4         51.773074            28.127576       8.83443  91.16557
#
#    adults_same_home  child_same_home    gini  child_medicaid  adult_medicaid  \
# 0         85.681144        85.293449  0.4645       41.277412       19.069355
# 1         85.681144        85.293449  0.4645       41.277412       19.069355
# 2         85.681144        85.293449  0.4645       41.277412       19.069355
# 3         85.681144        85.293449  0.4645       41.277412       19.069355
# 4         85.681144        85.293449  0.4645       41.277412       19.069355
#
#    Types.of.Health.Insurance.Coverage.by.Age..Total.  \
# 0                                             619708
# 1                                             619708
# 2                                             619708
# 3                                             619708
# 4                                             619708
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years.  \
# 0                                             132925
# 1                                             132925
# 2                                             132925
# 3                                             132925
# 4                                             132925
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage.  \
# 0                                             119778
# 1                                             119778
# 2                                             119778
# 3                                             119778
# 4                                             119778
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.employer.based.health.insurance.only  \
# 0                                              60573
# 1                                              60573
# 2                                              60573
# 3                                              60573
# 4                                              60573
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.direct.purchase.health.insurance.only  \
# 0                                               3538
# 1                                               3538
# 2                                               3538
# 3                                               3538
# 4                                               3538
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.Medicare.coverage.only  \
# 0                                                 42
# 1                                                 42
# 2                                                 42
# 3                                                 42
# 4                                                 42
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.Medicaid.means.tested.public.coverage.only  \
# 0                                              54868
# 1                                              54868
# 2                                              54868
# 3                                              54868
# 4                                              54868
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.TRICARE.military.health.coverage.only  \
# 0                                                757
# 1                                                757
# 2                                                757
# 3                                                757
# 4                                                757
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.VA.Health.Care.only  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage.  \
# 0                                              11109
# 1                                              11109
# 2                                              11109
# 3                                              11109
# 4                                              11109
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..With.employer.based.and.direct.purchase.coverage  \
# 0                                               1463
# 1                                               1463
# 2                                               1463
# 3                                               1463
# 4                                               1463
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..With.employer.based.and.Medicare.coverage  \
# 0                                                220
# 1                                                220
# 2                                                220
# 3                                                220
# 4                                                220
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..With.Medicare.and.Medicaid.means.tested.public.coverage  \
# 0                                                297
# 1                                                297
# 2                                                297
# 3                                                297
# 4                                                297
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..Other.private.only.combinations  \
# 0                                                450
# 1                                                450
# 2                                                450
# 3                                                450
# 4                                                450
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..Other.public.only.combinations  \
# 0                                                 28
# 1                                                 28
# 2                                                 28
# 3                                                 28
# 4                                                 28
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..Other.coverage.combinations  \
# 0                                               8651
# 1                                               8651
# 2                                               8651
# 3                                               8651
# 4                                               8651
#
#    Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..No.health.insurance.coverage  \
# 0                                               2038
# 1                                               2038
# 2                                               2038
# 3                                               2038
# 4                                               2038
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years.  \
# 0                                             159179
# 1                                             159179
# 2                                             159179
# 3                                             159179
# 4                                             159179
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.one.type.of.health.insurance.coverage.  \
# 0                                             137188
# 1                                             137188
# 2                                             137188
# 3                                             137188
# 4                                             137188
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.one.type.of.health.insurance.coverage..With.employer.based.health.insurance.only  \
# 0                                              87593
# 1                                              87593
# 2                                              87593
# 3                                              87593
# 4                                              87593
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.one.type.of.health.insurance.coverage..With.direct.purchase.health.insurance.only  \
# 0                                              11448
# 1                                              11448
# 2                                              11448
# 3                                              11448
# 4                                              11448
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.one.type.of.health.insurance.coverage..With.Medicare.coverage.only  \
# 0                                                243
# 1                                                243
# 2                                                243
# 3                                                243
# 4                                                243
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.one.type.of.health.insurance.coverage..With.Medicaid.means.tested.public.coverage.only  \
# 0                                              37023
# 1                                              37023
# 2                                              37023
# 3                                              37023
# 4                                              37023
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.one.type.of.health.insurance.coverage..With.TRICARE.military.health.coverage.only  \
# 0                                                636
# 1                                                636
# 2                                                636
# 3                                                636
# 4                                                636
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.one.type.of.health.insurance.coverage..With.VA.Health.Care.only  \
# 0                                                245
# 1                                                245
# 2                                                245
# 3                                                245
# 4                                                245
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.two.or.more.types.of.health.insurance.coverage.  \
# 0                                               9090
# 1                                               9090
# 2                                               9090
# 3                                               9090
# 4                                               9090
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.two.or.more.types.of.health.insurance.coverage..With.employer.based.and.direct.purchase.coverage  \
# 0                                               2205
# 1                                               2205
# 2                                               2205
# 3                                               2205
# 4                                               2205
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.two.or.more.types.of.health.insurance.coverage..With.employer.based.and.Medicare.coverage  \
# 0                                                 63
# 1                                                 63
# 2                                                 63
# 3                                                 63
# 4                                                 63
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.two.or.more.types.of.health.insurance.coverage..With.Medicare.and.Medicaid.means.tested.public.coverage  \
# 0                                               1670
# 1                                               1670
# 2                                               1670
# 3                                               1670
# 4                                               1670
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.two.or.more.types.of.health.insurance.coverage..Other.private.only.combinations  \
# 0                                                387
# 1                                                387
# 2                                                387
# 3                                                387
# 4                                                387
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.two.or.more.types.of.health.insurance.coverage..Other.public.only.combinations  \
# 0                                                 95
# 1                                                 95
# 2                                                 95
# 3                                                 95
# 4                                                 95
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.two.or.more.types.of.health.insurance.coverage..Other.coverage.combinations  \
# 0                                               4670
# 1                                               4670
# 2                                               4670
# 3                                               4670
# 4                                               4670
#
#    Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..No.health.insurance.coverage  \
# 0                                              12901
# 1                                              12901
# 2                                              12901
# 3                                              12901
# 4                                              12901
#
#    Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years.  \
# 0                                             241296
# 1                                             241296
# 2                                             241296
# 3                                             241296
# 4                                             241296
#
#    Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.one.type.of.health.insurance.coverage.  \
# 0                                             205776
# 1                                             205776
# 2                                             205776
# 3                                             205776
# 4                                             205776
#
#    Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.one.type.of.health.insurance.coverage..With.employer.based.health.insurance.only  \
# 0                                             151192
# 1                                             151192
# 2                                             151192
# 3                                             151192
# 4                                             151192
#
#    Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.one.type.of.health.insurance.coverage..With.direct.purchase.health.insurance.only  \
# 0                                              10829
# 1                                              10829
# 2                                              10829
# 3                                              10829
# 4                                              10829
#
#    Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.one.type.of.health.insurance.coverage..With.Medicare.coverage.only  \
# 0                                               2099
# 1                                               2099
# 2                                               2099
# ...
# 1                                                631
# 2                                                631
# 3                                                631
# 4                                                631
#
#    Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.two.or.more.types.of.health.insurance.coverage..Other.coverage.combinations  \
# 0                                               8733
# 1                                               8733
# 2                                               8733
# 3                                               8733
# 4                                               8733
#
#    Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..No.health.insurance.coverage  \
# 0                                              10144
# 1                                              10144
# 2                                              10144
# 3                                              10144
# 4                                              10144
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over.  \
# 0                                              86308
# 1                                              86308
# 2                                              86308
# 3                                              86308
# 4                                              86308
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.one.type.of.health.insurance.coverage.  \
# 0                                              20336
# 1                                              20336
# 2                                              20336
# 3                                              20336
# 4                                              20336
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.one.type.of.health.insurance.coverage..With.employer.based.health.insurance.only  \
# 0                                               2883
# 1                                               2883
# 2                                               2883
# 3                                               2883
# 4                                               2883
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.one.type.of.health.insurance.coverage..With.direct.purchase.health.insurance.only  \
# 0                                                261
# 1                                                261
# 2                                                261
# 3                                                261
# 4                                                261
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.one.type.of.health.insurance.coverage..With.Medicare.coverage.only  \
# 0                                              17173
# 1                                              17173
# 2                                              17173
# 3                                              17173
# 4                                              17173
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.one.type.of.health.insurance.coverage..With.TRICARE.military.health.coverage.only  \
# 0                                                  9
# 1                                                  9
# 2                                                  9
# 3                                                  9
# 4                                                  9
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.one.type.of.health.insurance.coverage..With.VA.Health.Care.only  \
# 0                                                 10
# 1                                                 10
# 2                                                 10
# 3                                                 10
# 4                                                 10
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage  \
# 0                                              65778
# 1                                              65778
# 2                                              65778
# 3                                              65778
# 4                                              65778
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.With.employer.based.and.direct.purchase.coverage  \
# 0                                                 44
# 1                                                 44
# 2                                                 44
# 3                                                 44
# 4                                                 44
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.With.employer.based.and.Medicare.coverage  \
# 0                                              19809
# 1                                              19809
# 2                                              19809
# 3                                              19809
# 4                                              19809
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.With.direct.purchase.and.Medicare.coverage  \
# 0                                              16686
# 1                                              16686
# 2                                              16686
# 3                                              16686
# 4                                              16686
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.With.Medicare.and.Medicaid.means.tested.public.coverage  \
# 0                                               9442
# 1                                               9442
# 2                                               9442
# 3                                               9442
# 4                                               9442
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.Other.private.only.combinations  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.Other.public.only.combinations  \
# 0                                               1289
# 1                                               1289
# 2                                               1289
# 3                                               1289
# 4                                               1289
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.Other.coverage.combinations  \
# 0                                              18508
# 1                                              18508
# 2                                              18508
# 3                                              18508
# 4                                              18508
#
#    Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..No.health.insurance.coverage  \
# 0                                                194
# 1                                                194
# 2                                                194
# 3                                                194
# 4                                                194
#
#      married   divorced  bad_english    poverty
# 0  42.023943  10.485747     7.930932  16.801532
# 1  42.023943  10.485747     7.930932  16.801532
# 2  42.023943  10.485747     7.930932  16.801532
# 3  42.023943  10.485747     7.930932  16.801532
# 4  42.023943  10.485747     7.930932  16.801532

# %%
# list(sal.columns.values)

# %%
##################################################################
# Utility functions
##################################################################

import matplotlib
matplotlib.style.use('ggplot')

def stats(inSet,feature):
    '''Statistics and distribution for features'''
    # look at descriptive stats and histogram for feature
    # col labels
    # print(inSet[1:1])
    # run stats
    plt.figure(figsize=(10,5))
    print('-'*100)
    print('Descriptive stats for %s' % feature)
    print('-'*100)
    print(inSet[feature].describe())
    print('\n')
    inSet[feature].plot(bins=10, kind='hist', alpha=0.5, subplots=True, color='Red')
    
    
stats(sal, 'salary')
# Out:
# ----------------------------------------------------------------------------------------------------
# Descriptive stats for salary
# ----------------------------------------------------------------------------------------------------
# count      2185.000000
# mean      48756.163901
# std       18379.834517
# min       10000.000000
# 25%       37455.000000
# 50%       44000.000000
# 75%       55656.000000
# max      207060.000000
# Name: salary, dtype: float64

# %%
##################################################################
# Descriptive stats
##################################################################

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
sal.describe()
# Out:
#        Unnamed: 0           zip         sup1         sup2         sup3  \
# count  2222.00000   2222.000000  2222.000000  2222.000000  2222.000000
# mean   1111.50000  56712.063006     1.431593     0.763726     0.624212
# std     641.58047  26523.312857     3.876824     2.774178     1.678481
# min       1.00000   1003.000000     0.000000     0.000000     0.000000
# 25%     556.25000  32898.500000     0.000000     0.000000     0.000000
# 50%    1111.50000  54751.000000     0.000000     0.000000     0.000000
# 75%    1666.75000  78712.000000     1.000000     0.000000     1.000000
# max    2222.00000  99775.000000    51.000000    35.000000    18.000000
#
#               sup4         sup5         salary   disabled  yearsinposition  \
# count  2222.000000  2222.000000    2185.000000       2222      2179.000000
# mean     49.639514     3.945995   48756.163901  0.0130513         5.689307
# std      97.573321    15.273516   18379.834517    0.11352         6.235899
# min       0.000000     0.000000   10000.000000      False         0.000000
# 25%       2.000000     0.000000   37455.000000          0         1.000000
# 50%      20.000000     0.000000   44000.000000          0         3.000000
# 75%      50.000000     1.000000   55656.000000          0         8.000000
# max    1063.000000   373.000000  207060.000000       True        42.000000
#
#        yearsinprofession          age      cred1      cred2        inst1  \
# count        2140.000000  2130.000000       2222       2222  2222.000000
# mean            9.327103    38.260094  0.0693069  0.0315032    16.674617
# 25%              23.392059      5.191452    87.201655         77.545698
# 50%              25.464391      8.834430    91.165570         82.252555
# 75%              29.612620     12.798345    94.808548         84.683353
# max              50.156703     38.665543    98.645799         89.934124
#
#        child_same_home         gini  child_medicaid  adult_medicaid  \
# count      2222.000000  2222.000000     2222.000000     2222.000000
# mean         83.811183     0.466544       30.883457        6.924946
# std           2.907775     0.022506        6.690233        2.808018
# min          73.380330     0.401300       14.486932        2.112643
# 25%          81.781441     0.452400       26.591324        4.659446
# 50%          84.099375     0.465300       30.643989        6.642990
# 75%          85.937300     0.476600       34.952407        8.372948
# max          91.236390     0.539900       60.881690       19.069355
#
#        Types.of.Health.Insurance.Coverage.by.Age..Total.  \
# count                                        2222.000000
# mean                                      1895281.853285
# std                                       2885960.304511
# min                                         29657.000000
# 25%                                        197209.000000
# 50%                                        631909.000000
# 75%                                       2330315.000000
# max                                      19679485.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years.  \
# count                                        2222.000000
# mean                                       455043.003150
# std                                        689453.069379
# min                                          5854.000000
# 25%                                         42116.000000
# 50%                                        152102.000000
# 75%                                        587326.000000
# max                                       4445849.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage.  \
# count                                        2222.000000
# mean                                       399161.483348
# std                                        607956.886837
# min                                          4978.000000
# 25%                                         37803.000000
# 50%                                        134030.000000
# 75%                                        510910.000000
# max                                       3988732.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.employer.based.health.insurance.only  \
# count                                        2222.000000
# mean                                       225378.172367
# std                                        338062.864566
# min                                          2470.000000
# 25%                                         20093.000000
# 50%                                         68934.000000
# 75%                                        309391.000000
# max                                       2302382.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.direct.purchase.health.insurance.only  \
# count                                        2222.000000
# mean                                        23815.917192
# std                                         36627.881853
# min                                           107.000000
# 25%                                          2185.000000
# 50%                                          7432.500000
# 75%                                         33508.000000
# max                                        217335.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.Medicare.coverage.only  \
# count                                        2222.000000
# mean                                         1133.684968
# std                                          1862.055878
# min                                             0.000000
# 25%                                            50.000000
# 50%                                           269.000000
# 75%                                          1201.000000
# max                                         12005.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.Medicaid.means.tested.public.coverage.only  \
# count                                        2222.000000
# mean                                       142414.013951
# std                                        235208.250750
# min                                          1389.000000
# 25%                                         13546.000000
# 50%                                         52019.000000
# 75%                                        170203.000000
# max                                       1448122.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.TRICARE.military.health.coverage.only  \
# count                                        2222.000000
# mean                                         6309.062556
# std                                         12049.078616
# min                                            38.000000
# 25%                                           388.000000
# 50%                                          1763.000000
# 75%                                          6188.000000
# max                                         73201.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.VA.Health.Care.only  \
# count                                        2222.000000
# mean                                          110.632313
# std                                           148.831064
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            47.000000
# 75%                                           168.000000
# max                                           980.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage.  \
# count                                        2222.000000
# mean                                        22595.378488
# std                                         34608.880726
# min                                           272.000000
# 25%                                          2123.000000
# 50%                                          8651.000000
# 75%                                         29145.000000
# max                                        261906.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..With.employer.based.and.direct.purchase.coverage  \
# count                                        2222.000000
# mean                                         5845.338884
# std                                         10386.567594
# min                                            51.000000
# 25%                                           546.000000
# 50%                                          1567.000000
# 75%                                          6741.000000
# max                                         81937.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..With.employer.based.and.Medicare.coverage  \
# count                                        2222.000000
# mean                                          168.801530
# std                                           474.540162
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            28.000000
# 75%                                           174.000000
# max                                          3534.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..With.Medicare.and.Medicaid.means.tested.public.coverage  \
# count                                        2222.000000
# mean                                          938.752475
# std                                          1463.783182
# min                                             0.000000
# 25%                                            68.000000
# 50%                                           297.000000
# 75%                                          1283.500000
# max                                          8927.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..Other.private.only.combinations  \
# count                                        2222.000000
# mean                                         1865.681818
# std                                          3549.356700
# min                                             0.000000
# 25%                                           135.000000
# 50%                                           668.000000
# 75%                                          1791.000000
# max                                         23336.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..Other.public.only.combinations  \
# count                                        2222.000000
# mean                                           53.362286
# std                                            80.857709
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            23.000000
# 75%                                            77.000000
# max                                           426.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..Other.coverage.combinations  \
# count                                        2222.000000
# mean                                        13723.441494
# ...
# 75%                                         69697.000000
# max                                        698138.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.one.type.of.health.insurance.coverage..With.TRICARE.military.health.coverage.only  \
# count                                        2222.000000
# mean                                           83.119262
# std                                           141.292228
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            17.000000
# 75%                                           102.000000
# max                                           678.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.one.type.of.health.insurance.coverage..With.VA.Health.Care.only  \
# count                                        2222.000000
# mean                                          134.139064
# std                                           185.678022
# min                                             0.000000
# 25%                                             9.000000
# 50%                                            61.000000
# 75%                                           201.000000
# max                                           935.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage  \
# count                                        2222.000000
# mean                                       158656.151665
# std                                        237639.851040
# min                                          2298.000000
# 25%                                         16700.000000
# 50%                                         65778.000000
# 75%                                        213083.000000
# max                                       1772442.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.With.employer.based.and.direct.purchase.coverage  \
# count                                        2222.000000
# mean                                          250.040504
# std                                           479.836653
# min                                             0.000000
# 25%                                            15.000000
# 50%                                            55.000000
# 75%                                           294.000000
# max                                          3773.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.With.employer.based.and.Medicare.coverage  \
# count                                        2222.000000
# mean                                        48645.462646
# std                                         79846.618915
# min                                           340.000000
# 25%                                          4846.250000
# 50%                                         17508.000000
# 75%                                         61199.000000
# max                                        636952.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.With.direct.purchase.and.Medicare.coverage  \
# count                                        2222.000000
# mean                                        39912.031053
# std                                         55069.679811
# min                                           289.000000
# 25%                                          5324.000000
# 50%                                         18753.000000
# 75%                                         54850.000000
# max                                        358740.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.With.Medicare.and.Medicaid.means.tested.public.coverage  \
# count                                        2222.000000
# mean                                        21917.255626
# std                                         51382.074272
# min                                            97.000000
# 25%                                          1295.000000
# 50%                                          6068.000000
# 75%                                         21103.000000
# max                                        365795.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.Other.private.only.combinations  \
# count                                        2222.000000
# mean                                           40.810981
# std                                            68.121983
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            10.000000
# 75%                                            58.000000
# max                                           420.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.Other.public.only.combinations  \
# count                                        2222.000000
# mean                                         4016.001350
# std                                          5095.067497
# min                                            51.000000
# 25%                                           427.000000
# 50%                                          1906.000000
# 75%                                          5354.000000
# max                                         26310.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.Other.coverage.combinations  \
# count                                        2222.000000
# mean                                        43874.549505
# std                                         55875.331838
# min                                           592.000000
# 25%                                          5286.000000
# 50%                                         19235.000000
# 75%                                         72615.000000
# max                                        380724.000000
#
#        Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..No.health.insurance.coverage  \
# count                                        2222.000000
# mean                                         3225.207021
# std                                          6885.935280
# min                                             0.000000
# 25%                                           110.000000
# 50%                                           436.000000
# 75%                                          2616.000000
# max                                         41859.000000
#
#            married     divorced  bad_english      poverty
# count  2222.000000  2222.000000  2222.000000  2222.000000
# mean     46.505610    10.653497     6.581784    17.348598
# std       4.271424     1.742871     5.333502     5.353055
# min      33.378690     6.045561     0.814731     8.010233
# 25%      45.340358     9.630605     2.580717    14.386391
# 50%      47.386348    10.785170     4.580937    16.091883
# 75%      49.452002    11.681655     9.074155    19.279498
# max      55.634702    15.737692    31.824588    34.592270

# %%
##################################################################
# Get features names
##################################################################
sal.columns.to_series().groupby(sal.dtypes).groups
# Out:
# {dtype('bool'): ['disabled', 'cred1', 'cred2'],
#  dtype('int64'): ['Unnamed: 0',
#   'zip',
#   'sup1',
#   'sup2',
#   'sup3',
#   'sup4',
#   'sup5',
#   'inst1',
#   'inst2',
#   'inst3',
#   'inst4',
#   'inst5',
#   'ZCTA5',
#   'cbsa',
#   'total_population',
#   'Median_Household_Income',
#   'asian_api_total',
#   'latino_total',
#   'white_total',
#   'native_american_total',
#   'two_race_or_more_total',
#   'median_rent',
#   'Sex.by.Age..Male.',
#   'Sex.by.Age..Male..Under.5.years',
#   'Sex.by.Age..Male..5.to.9.years',
#   'Sex.by.Age..Male..10.to.14.years',
#   'Sex.by.Age..Male..15.to.17.years',
#   'Sex.by.Age..Male..18.and.19.years',
#   'Sex.by.Age..Male..20.years',
#   'Sex.by.Age..Male..21.years',
#   'Sex.by.Age..Male..22.to.24.years',
#   'Sex.by.Age..Male..25.to.29.years',
#   'Sex.by.Age..Male..30.to.34.years',
#   'Sex.by.Age..Male..35.to.39.years',
#   'Sex.by.Age..Male..40.to.44.years',
#   'Sex.by.Age..Male..45.to.49.years',
#   'Sex.by.Age..Male..50.to.54.years',
#   'Sex.by.Age..Male..55.to.59.years',
#   'Sex.by.Age..Male..60.and.61.years',
#   'Sex.by.Age..Male..62.to.64.years',
#   'Sex.by.Age..Male..65.and.66.years',
#   'Sex.by.Age..Male..67.to.69.years',
#   'Sex.by.Age..Male..70.to.74.years',
#   'Sex.by.Age..Male..75.to.79.years',
#   'Sex.by.Age..Male..80.to.84.years',
#   'Sex.by.Age..Male..85.years.and.over',
#   'Sex.by.Age..Female.',
#   'Sex.by.Age..Female..Under.5.years',
#   'Sex.by.Age..Female..5.to.9.years',
#   'Sex.by.Age..Female..10.to.14.years',
#   'Sex.by.Age..Female..15.to.17.years',
#   'Sex.by.Age..Female..18.and.19.years',
#   'Sex.by.Age..Female..20.years',
#   'Sex.by.Age..Female..21.years',
#   'Sex.by.Age..Female..22.to.24.years',
#   'Sex.by.Age..Female..25.to.29.years',
#   'Sex.by.Age..Female..30.to.34.years',
#   'Sex.by.Age..Female..35.to.39.years',
#   'Sex.by.Age..Female..40.to.44.years',
#   'Sex.by.Age..Female..45.to.49.years',
#   'Sex.by.Age..Female..50.to.54.years',
#   'Sex.by.Age..Female..55.to.59.years',
#   'Sex.by.Age..Female..60.and.61.years',
#   'Sex.by.Age..Female..62.to.64.years',
#   'Sex.by.Age..Female..65.and.66.years',
#   'Sex.by.Age..Female..67.to.69.years',
#   'Sex.by.Age..Female..70.to.74.years',
#   'Sex.by.Age..Female..75.to.79.years',
#   'Sex.by.Age..Female..80.to.84.years',
#   'Sex.by.Age..Female..85.years.and.over',
#   'Types.of.Health.Insurance.Coverage.by.Age..Total.',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years.',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage.',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.employer.based.health.insurance.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.direct.purchase.health.insurance.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.Medicare.coverage.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.Medicaid.means.tested.public.coverage.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.TRICARE.military.health.coverage.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.one.type.of.health.insurance.coverage..With.VA.Health.Care.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage.',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..With.employer.based.and.direct.purchase.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..With.employer.based.and.Medicare.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..With.Medicare.and.Medicaid.means.tested.public.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..Other.private.only.combinations',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..Other.public.only.combinations',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..With.two.or.more.types.of.health.insurance.coverage..Other.coverage.combinations',
#   'Types.of.Health.Insurance.Coverage.by.Age..Under.18.years..No.health.insurance.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years.',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.one.type.of.health.insurance.coverage.',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.one.type.of.health.insurance.coverage..With.employer.based.health.insurance.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.one.type.of.health.insurance.coverage..With.direct.purchase.health.insurance.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.one.type.of.health.insurance.coverage..With.Medicare.coverage.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.one.type.of.health.insurance.coverage..With.Medicaid.means.tested.public.coverage.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.one.type.of.health.insurance.coverage..With.TRICARE.military.health.coverage.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.one.type.of.health.insurance.coverage..With.VA.Health.Care.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.two.or.more.types.of.health.insurance.coverage.',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.two.or.more.types.of.health.insurance.coverage..With.employer.based.and.direct.purchase.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.two.or.more.types.of.health.insurance.coverage..With.employer.based.and.Medicare.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.two.or.more.types.of.health.insurance.coverage..With.Medicare.and.Medicaid.means.tested.public.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.two.or.more.types.of.health.insurance.coverage..Other.private.only.combinations',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.two.or.more.types.of.health.insurance.coverage..Other.public.only.combinations',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..With.two.or.more.types.of.health.insurance.coverage..Other.coverage.combinations',
#   'Types.of.Health.Insurance.Coverage.by.Age..18.to.34.years..No.health.insurance.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years.',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.one.type.of.health.insurance.coverage.',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.one.type.of.health.insurance.coverage..With.employer.based.health.insurance.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.one.type.of.health.insurance.coverage..With.direct.purchase.health.insurance.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.one.type.of.health.insurance.coverage..With.Medicare.coverage.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.one.type.of.health.insurance.coverage..With.Medicaid.means.tested.public.coverage.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.one.type.of.health.insurance.coverage..With.TRICARE.military.health.coverage.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.one.type.of.health.insurance.coverage..With.VA.Health.Care.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.two.or.more.types.of.health.insurance.coverage.',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.two.or.more.types.of.health.insurance.coverage..With.employer.based.and.direct.purchase.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.two.or.more.types.of.health.insurance.coverage..With.employer.based.and.Medicare.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.two.or.more.types.of.health.insurance.coverage..With.direct.purchase.and.Medicare.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.two.or.more.types.of.health.insurance.coverage..With.Medicare.and.Medicaid.means.tested.public.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.two.or.more.types.of.health.insurance.coverage..Other.private.only.combinations',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.two.or.more.types.of.health.insurance.coverage..Other.public.only.combinations',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..With.two.or.more.types.of.health.insurance.coverage..Other.coverage.combinations',
#   'Types.of.Health.Insurance.Coverage.by.Age..35.to.64.years..No.health.insurance.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over.',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.one.type.of.health.insurance.coverage.',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.one.type.of.health.insurance.coverage..With.employer.based.health.insurance.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.one.type.of.health.insurance.coverage..With.direct.purchase.health.insurance.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.one.type.of.health.insurance.coverage..With.Medicare.coverage.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.one.type.of.health.insurance.coverage..With.TRICARE.military.health.coverage.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.one.type.of.health.insurance.coverage..With.VA.Health.Care.only',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.With.employer.based.and.direct.purchase.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.With.employer.based.and.Medicare.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.With.direct.purchase.and.Medicare.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.With.Medicare.and.Medicaid.means.tested.public.coverage',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.Other.private.only.combinations',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.Other.public.only.combinations',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..With.two.or.more.types.of.health.insurance.coverage.Other.coverage.combinations',
#   'Types.of.Health.Insurance.Coverage.by.Age..65.years.and.over..No.health.insurance.coverage'],
#  dtype('float64'): ['salary',
#   'yearsinposition',
#   'yearsinprofession',
#   'age',
#   'instbudget',
#   'instsize',
#   'no_male_hs',
#   'no_female_hs',
#   'no_hs',
#   'at_least_hs_male',
#   'at_least_hs_female',
#   'at_least_hs',
#   'hs_some_college_male',
#   'hs_some_college_female',
#   'hs_some_college',
#   'bachelors_male',
#   'bachelors_female',
#   'bachelors',
#   'at_least_bach_male',
#   'at_least_bach_female',
#   'at_least_bach',
#   'graduate_male',
#   'graduate_female',
#   'graduate',
#   'hispanic',
#   'white',
#   'black',
#   'native_american',
#   'asian_api',
#   'two_race_or_more',
#   'male_unemployment',
#   'female_unemployment',
#   'snap',
#   'renter',
#   'owner',
#   'under_18',
#   'over_65',
#   'commute_over_60',
#   'full_time',
#   'part_time',
#   'high_rent_burden',
#   'extreme_rent_burden',
#   'foreign_born',
#   'US_born',
#   'adults_same_home',
#   'child_same_home',
#   'gini',
#   'child_medicaid',
#   'adult_medicaid',
#   'married',
#   'divorced',
#   'bad_english',
#   'poverty'],
#  dtype('O'): ['function.',
#   'gender',
#   'race',
#   'highestdegree',
#   'city',
#   'state',
#   'country',
#   'category',
#   'insttype']}

# %%
##################################################################
# Eliminate rows with missing Y values (NaN)
# removing salary as we cannot impute that
##################################################################

sal['missingSalary'] = pd.isnull(sal['salary'])
salary_clean = sal[(sal.missingSalary == False)]

# %%
##################################################################
# Subset X Numerical Features
##################################################################

X_numeric_features = [
  'zip',
  'sup1',
  'sup2',
  'sup3',
  'sup4',
  'sup5',
  'inst1',
  'inst2',
  'inst3',
  'inst4',
  'inst5',
  'ZCTA5',
  'cbsa',
  'total_population',
  'Median_Household_Income',
  'asian_api_total',
  'latino_total',
  'white_total',
  'native_american_total',
  'two_race_or_more_total',
  'median_rent',
  'yearsinposition',
  'yearsinprofession',
  'age',
  'instbudget',
  'instsize',
  'no_male_hs',
  'no_female_hs',
  'no_hs',
  'at_least_hs_male',
  'at_least_hs_female',
  'at_least_hs',
  'hs_some_college_male',
  'hs_some_college_female',
  'hs_some_college',
  'bachelors_male',
  'bachelors_female',
  'bachelors',
  'at_least_bach_male',
  'at_least_bach_female',
  'at_least_bach',
  'graduate_male',
  'graduate_female',
  'graduate',
  'hispanic',
  'white',
  'black',
  'native_american',
  'asian_api',
  'two_race_or_more',
  'male_unemployment',
  'female_unemployment',
  'snap',
  'renter',
  'owner',
  'under_18',
  'over_65',
  'commute_over_60',
  'full_time',
  'part_time',
  'high_rent_burden',
  'extreme_rent_burden',
  'foreign_born',
  'US_born',
  'adults_same_home',
  'child_same_home',
  'gini',
  'child_medicaid',
  'adult_medicaid',
  'married',
  'divorced',
  'bad_english',
  'poverty'    
]

X_numeric = salary_clean[X_numeric_features]

# %%
##################################################################
# Automating the dummy variable creation
# Subset X categorical features and create dummy variables
# DOC: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html
##################################################################

X_categorical_features = ['function.', 'gender', 'race', 'highestdegree', 'category', 'insttype', 'city', 'state']
# check groups
X_categorical_groups = salary_clean[X_categorical_features].columns.to_series().groupby(sal.dtypes).groups
print(X_categorical_groups)

def toDummy(vect):
    appended_data = []
    
    for val in X_categorical_features:
        dummy = pd.get_dummies(salary_clean[val])
        appended_data.append(dummy)

    appended_data = pd.concat(appended_data, axis=1)
    return appended_data

X_dummy = toDummy(X_categorical) 
X_dummy_features = X_dummy.as_matrix()

# check shape of dummy dataframe
print(X_dummy.shape)
# Out:
# {dtype('O'): ['function.', 'gender', 'race', 'highestdegree', 'category', 'insttype', 'city', 'state']}
# (2185, 288)

# %%
##################################################################
# impute missing values in numerical features
# DOC: http://scikit-learn.org/stable/modules/preprocessing.html
##################################################################

# default is imputing it with the mean
from sklearn.preprocessing import Imputer
imp = Imputer(strategy='mean')
imp.fit(X_numeric)
X_numeric_imputed = imp.transform(X_numeric)

# %%
##################################################################
# create X - concat numeric and dummy variables
##################################################################

X = np.concatenate((X_dummy_features, X_numeric_imputed), axis=1)

# %%
##################################################################
# create Y - subset salary
##################################################################

y = salary_clean['salary'].values
y[0:10]
# Out:
# array([ 77308.,  38120.,  55335.,  70863.,  56557.,  48489.,  55557.,
#         38120.,  40500.,  40500.])

# %%
# check imputed values
np.isnan(X_numeric_imputed).sum()
# Out:
# 0

# %%
# create training and test sets
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
         X, y, test_size=0.3, random_state=0)

# %%
# keep track of variance on test data, to graph
var_to_graph = {}
# bring residual sum of squares from regression1.ipynb
var_to_graph['simpReg'] = 265376883.08

# %%
def report(model, modelLabel):
    # The coefficients
    # print('Coefficients: \n', model.coef_)
    # The mean square error
    print('-' * 100)
    print('#### TEST SET #### ')
    print('-' * 100)    
    # The intercept
    print('Intercept: \n', model.intercept_)
    print('-' * 100)        
    print("Residual sum of squares, test data: %.2f"
          % np.mean((model.predict(X_test) - y_test) ** 2))        
    # Explained variance score: 1 is perfect prediction
    print('-' * 100)
    print('Variance score, training data: %.2f' % model.score(X_test, y_test))
    #vector of prediction error
    print('-' * 100)
    print('Distribution of prediction error on test data:')
    predError = model.predict(X_test) - y_test
    plt.hist(predError)
    plt.show()  

    print('-' * 100)
    print('#### TRAIN SET #### ')
    print('-' * 100)   
    print("Residual sum of squares, training data: %.2f"
          % np.mean((model.predict(X_train) - y_train) ** 2))
    print('-' * 100)   
    print('Variance score, training data: %.2f' % model.score(X_train, y_train))
    print('-' * 100)

    print('Distribution of prediction error on training data:')
    predError = model.predict(X_train) - y_train
    plt.hist(predError)
    plt.show()

    var_to_graph[modelLabel] = np.mean((model.predict(X_test) - y_test) ** 2)
    
def plotModel(model):
    print('-' * 100)   
    print('Plot TEST set:')
    print('-' * 100)   
    
    x = model.predict(X_test)
    plt.scatter(x, y_test,  color='black', alpha=0.5)
    plt.plot(x, x, color='red',
             linewidth=1)
    plt.show()

    print('-' * 100)   
    print('Plot TRAIN set:')
    print('-' * 100)

    x = model.predict(X_train)
    plt.scatter(x, y_train,  color='black', alpha=0.5)
    plt.plot(x, x, color='red',
             linewidth=1)
    plt.show()

# %%
from sklearn import datasets, linear_model
# DOC: http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
##################################################################
# Model LinearRegression
##################################################################

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
X_train_no_intercept = X_train
X_train = X_train.reshape(-1, X_train.shape[1])
regr.fit(X_train, y_train)

report(regr, 'multReg_linear')
plotModel(regr)
# Out:
# ----------------------------------------------------------------------------------------------------
# #### TEST SET ####
# ----------------------------------------------------------------------------------------------------
# Intercept:
#  256677.388817
# ----------------------------------------------------------------------------------------------------
# Residual sum of squares, test data: 96616331.81
# ----------------------------------------------------------------------------------------------------
# Variance score, training data: 0.74
# ----------------------------------------------------------------------------------------------------
# Distribution of prediction error on test data:
# ----------------------------------------------------------------------------------------------------
# #### TRAIN SET ####
# ----------------------------------------------------------------------------------------------------
# Residual sum of squares, training data: 58337472.82
# ----------------------------------------------------------------------------------------------------
# Variance score, training data: 0.82
# ----------------------------------------------------------------------------------------------------
# Distribution of prediction error on training data:
# ----------------------------------------------------------------------------------------------------
# Plot TEST set:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Plot TRAIN set:
# ----------------------------------------------------------------------------------------------------

# %%
##################################################################
# Model PolynomialFeatures
##################################################################

from sklearn.preprocessing import PolynomialFeatures
# DOC: http://scikit-learn.org/stable/modules/preprocessing.html

# make it polynomial - include all possible interactions
poly = PolynomialFeatures(2)
X_poly = poly.fit_transform(X)

# %%
# create training and test sets
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
         X_poly, y, test_size=0.3, random_state=0)

# %%
## POLYNOMINAL 
# Create linear regression object
poly = linear_model.LinearRegression(normalize=True)

# Train the model using the training sets
X_train_no_intercept = X_train
X_train = X_train.reshape(-1, X_train.shape[1])
poly.fit(X_train, y_train)

report(poly, 'multReg_poly' )
# Out:
# ----------------------------------------------------------------------------------------------------
# #### TEST SET ####
# ----------------------------------------------------------------------------------------------------
# Intercept:
#  2.31029107827e+17
# ----------------------------------------------------------------------------------------------------
# Residual sum of squares, test data: 142364981005734464138602666791010304.00
# ----------------------------------------------------------------------------------------------------
# Variance score, training data: -379551185193916796365701120.00
# ----------------------------------------------------------------------------------------------------
# Distribution of prediction error on test data:
# ----------------------------------------------------------------------------------------------------
# #### TRAIN SET ####
# ----------------------------------------------------------------------------------------------------
# Residual sum of squares, training data: 60650521.74
# ----------------------------------------------------------------------------------------------------
# Variance score, training data: 0.81
# ----------------------------------------------------------------------------------------------------
# Distribution of prediction error on training data:

# %%
# reguralization - adds a contant to the features. if anything is extreme there is less chance of it afecting the output


## RIDGE REGRESSION
# DOC: http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html

# create training and test sets
from sklearn.cross_validation import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
         X, y, test_size=0.3, random_state=0)

# Create linear regression object
regr_ridge = linear_model.Ridge(alpha = 0.8)

# Train the model using the training sets
X_train_no_intercept = X_train
X_train = X_train.reshape(-1, X_train.shape[1])
regr_ridge.fit(X_train, y_train)

report( regr_ridge ,'multReg_ridge' )
plotModel(regr_ridge)
# Out:
# ----------------------------------------------------------------------------------------------------
# #### TEST SET ####
# ----------------------------------------------------------------------------------------------------
# Intercept:
#  -27587.6113376
# ----------------------------------------------------------------------------------------------------
# Residual sum of squares, test data: 85437210.64
# ----------------------------------------------------------------------------------------------------
# Variance score, training data: 0.77
# ----------------------------------------------------------------------------------------------------
# Distribution of prediction error on test data:
# ----------------------------------------------------------------------------------------------------
# #### TRAIN SET ####
# ----------------------------------------------------------------------------------------------------
# Residual sum of squares, training data: 59752915.04
# ----------------------------------------------------------------------------------------------------
# Variance score, training data: 0.81
# ----------------------------------------------------------------------------------------------------
# Distribution of prediction error on training data:
# ----------------------------------------------------------------------------------------------------
# Plot TEST set:
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Plot TRAIN set:
# ----------------------------------------------------------------------------------------------------

# %%
# bar graph of dict with Residual Sum of Squares on test datasets
var_to_graph['multReg_poly'] = 0
plt.bar(range(len(var_to_graph)), var_to_graph.values(), align='center')
plt.xticks(range(len(var_to_graph)), var_to_graph.keys())

plt.show()
